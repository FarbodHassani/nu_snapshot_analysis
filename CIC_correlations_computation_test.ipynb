# %%
import numpy as np
import pandas as pd
import pickle
from mpi4py import MPI
import os
import sys
from tqdm import tqdm
from collections import defaultdict
import dill
sys.path.append('/mn/stornext/u3/hassanif/neutrino_niayesh/Analysis/nu_code/library_snapshot')
import sys
import os
sys.path.append('/mn/stornext/u3/hassanif/neutrino_niayesh/Analysis/nu_code/')
# from library_snapshot import bulk_velocity # For the x-y analysis
from computation_CIC_alpha_correlations_bulk import perform_analysis_alpha_correlation, compute_correlations
# import readsnap
# from analysis_functions import perform_analysis
# from analysis_functions import load_halo_data
from analysis_functions import *
# from computation_xy import *

# %%
boxsize = 1024
# bulk_species ="cdm"
mass_limit = [1.e13]
save_path ="./output"
file_path ="./../Run_Bulk_velocities_CIC/L_1024_Ngrid_512/0.15ev/"
ngrid_min =4
ngrid_max =5
ngrid_step =1
ngrid_list = np.arange(ngrid_min, ngrid_max, ngrid_step)
boxsize =1024
sims =["0.15ev"]
num_pcl =512
type_data ="normal"
specs =["L_1024_Ngrid_512"]
ngrid =5

# %%
perform_analysis_alpha_correlation(sims, specs, mass_limit, boxsize, save_path, ngrid_list, "rho1rho2", 1)
# Out:
# Perform analysis finished!

# %%
cdm_path = f"{file_path}/cdm/output/data_ngrid_{ngrid}_sim_{sims[0]}_{specs[0]}_cdm.pickle"

# %%
sb1 = load(cdm_path);
# bulk_all_2 = load(cdm_path);
p1x, p1y, p1z = sb1['P_x'].astype(np.float64), sb1['P_y'].astype(np.float64), sb1['P_z'].astype(np.float64)

# %%
bulk_all_1['sub_box_data']['P_x']
# Out:
# array([[[-7.8507410e+06,  1.6143381e+07,  5.3942828e+07,  9.1813024e+07,
#           4.5718268e+07],
#         [ 3.2890668e+07,  1.8426048e+07,  3.0653226e+07,  8.6531864e+07,
#           1.1540176e+08],
#         [ 2.7093562e+07,  1.3414269e+07, -3.1973316e+07, -1.7170440e+07,
#          -4.4714550e+06],
#         [-2.0389514e+07, -1.8711804e+07, -8.6845920e+07, -5.1878404e+07,
#          -5.3248444e+07],
#         [ 2.6593232e+07,  2.4865010e+06, -4.0414600e+07,  4.1422284e+07,
#          -2.3311208e+06]],
#
#        [[-6.1808640e+06, -2.2389688e+07, -2.9986962e+07, -4.7761208e+07,
#          -9.4762584e+07],
#         [ 2.6340260e+07,  2.0555836e+07,  3.0184164e+07,  1.4780192e+07,
#           1.2040407e+07],
#         [ 7.7323296e+07,  1.2175863e+08,  5.7071288e+07,  7.5036504e+07,
#           9.0440912e+07],
#         [ 1.9689272e+07,  5.1206528e+07, -4.4765756e+07,  1.2110402e+07,
#           4.1851676e+07],
# ...

# %%
sb1 = bulk_all_1['sub_box_data']

# %%
sb1['P_x']

# %%
print(type(sb1['P_x']))
print(np.shape(sb1['P_x']))
# Out:
# <class 'numpy.ndarray'>
# (5, 5, 5)

# %% [markdown]
# # Test for the full runs

# %%
import sys
sys.path.append('/mn/stornext/u3/hassanif/neutrino_niayesh/Analysis/nu_code/')
from library_snapshot import computation_CIC_alpha_correlations_bulk
from computation_CIC_alpha_correlations_bulk import perform_analysis_alpha_correlation
# Out:
# Traceback (most recent call last):
#
#   File ~/data/python_env/my_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3550 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 3
#     from library_snapshot import computation_CIC_alpha_correlations_bulk
#
#   File /mn/stornext/d14/gravity/personal/hassanif/projects/Neutrino_Niayesh/Analysis/nu_code/library_snapshot/computation_CIC_alpha_correlations_bulk.py:275
#     weight_1 =
#                ^
# SyntaxError: invalid syntax

# %%
#################
## Global variables
#################

#["0.0ev", "0.15ev", "0.3ev", "0.6ev", "0.9ev"];
sims= ["0.0ev", "0.15ev", "0.3ev", "0.6ev", "0.9ev"]
specs = ["L_1024_Ngrid_1024"]
Mass_cuts = [
    1e12, 2e12, 3e12, 4e12, 5e12, 6e12, 7e12, 8e12, 9e12, 1e13,
    2e13, 3e13, 4e13, 5e13, 6e13, 7e13, 8e13, 9e13, 1e14, 2e14
];
boxsize = 1024
ngrid_max = 90
halo_dir = "/mn/stornext/u3/hassanif/neutrino_niayesh/simulations/"
ngrid_step = 1
ngrid_list = range(1, ngrid_max, ngrid_step)
num_cores = 5
save_path = "./correlations_xy_"+specs[0]

# %%
perform_analysis_alpha_correlation(sims, specs, Mass_cuts, boxsize, save_path, ngrid_list, 1)
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 perform_analysis_alpha_correlation(sims, specs, Mass_cuts, boxsize, save_path, ngrid_list, 1)
#
# File ~/neutrino_niayesh/Analysis/nu_code/library_snapshot/computation_CIC_alpha_correlations_bulk.py:77, in perform_analysis_alpha_correlation(sims, specs, Mass_cuts, boxsize, save_path, ngrid_list, num_cores)
#      75     spec = specs[spec_index]
#      76     sim = sims[sim_index]
# ---> 77     analyze_and_save_for_ngrid(spec, sim, Mass_cut, ngrid_list, save_path, boxsize)
#      79 # Wait for all processes to complete
#      80 comm.Barrier()
#
# File ~/neutrino_niayesh/Analysis/nu_code/library_snapshot/computation_CIC_alpha_correlations_bulk.py:324, in analyze_and_save_for_ngrid(spec, sim, Mass_cut, ngrid_list, save_path, boxsize)
# ...

# %%
"/mn/stornext/u3/hassanif/neutrino_niayesh/Analysis/Run_Bulk_velocities_CIC/L_1024_Ngrid_1024/0.0ev/cdm/output/data_ngrid_12_sim_0.0ev_L_1024_Ngrid_1024_cdm.pickle"
# Out:
# '/mn/stornext/u3/hassanif/neutrino_niayesh/Analysis/Run_Bulk_velocities_CIC/L_1024_Ngrid_1024/0.0ev/cdm/output/data_ngrid_12_sim_0.0ev_L_1024_Ngrid_1024_cdm.pickle'

# %%
Mass_cuts = [
    1e12, 2e12, 3e12, 4e12, 5e12, 6e12, 7e12, 8e12, 9e12, 1e13,
    2e13, 3e13, 4e13, 5e13, 6e13, 7e13, 8e13, 9e13, 1e14, 2e14
];

# %%
np.shape(Mass_cuts)
# Out:
# (20,)
